# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pycountry

# %%
df = pd.read_csv("../Raw/dataset_2026-04-06T13_56_46.174114850Z_DEFAULT_INTEGRATION_IMF.STA_IIP_13.0.0.csv")
df
# Out:
# /var/folders/_x/74827dzs033cwdj2j4gch59r0000gn/T/ipykernel_7469/3541858851.py:1: DtypeWarning: Columns (0: IFS_FLAG) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Raw/dataset_2026-04-06T13_56_46.174114850Z_DEFAULT_INTEGRATION_IMF.STA_IIP_13.0.0.csv")
#                     DATASET                   SERIES_CODE OBS_MEASURE  \
# 0       IMF.STA:IIP(13.0.0)    NIC.A_P.O_F2_S12R_NV.USD.A   OBS_VALUE
# 1       IMF.STA:IIP(13.0.0)     NIC.L_P.O_F4_S13_NV.USD.A   OBS_VALUE
# 2       IMF.STA:IIP(13.0.0)         NIC.L_P.O_F2_NV.USD.Q   OBS_VALUE
# 3       IMF.STA:IIP(13.0.0)    NIC.NETAL_P.NIIP_AFR.USD.A   OBS_VALUE
# 4       IMF.STA:IIP(13.0.0)   NIC.A_P.O_F4_S1Z_S_NV.USD.Q   OBS_VALUE
# ...                     ...                           ...         ...
# 135142  IMF.STA:IIP(13.0.0)  KNA.A_P.P_F3_S12R_L_MV.XDC.A   OBS_VALUE
# 135143  IMF.STA:IIP(13.0.0)     POL.L_P.O_F81_S1V_L.USD.Q   OBS_VALUE
# ...

# %%
# Get iso3 codes for both origin and destination
ctr_to_iso3 = {country.name: country.alpha_3 for country in pycountry.countries}
df["iso3"] = df["COUNTRY"].map(ctr_to_iso3)
# Out:
# /var/folders/_x/74827dzs033cwdj2j4gch59r0000gn/T/ipykernel_7469/1344195178.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["iso3"] = df["COUNTRY"].map(ctr_to_iso3)

# %%
df["INDICATOR"].value_counts().head(30)
# Out:
# INDICATOR
# Other investment                                                                                                 1022
# International Investment Position                                                                                1020
# Other investment, Currency and deposits                                                                          1016
# Other investment, Loans                                                                                          1012
# Direct investment                                                                                                1004
# Portfolio investment                                                                                             1003
# Other investment, Currency and deposits, Deposit taking corporations, except the Central Bank                     999
# Direct investment, Equity and investment fund shares                                                              983
# ...
