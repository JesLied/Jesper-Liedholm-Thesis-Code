# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import util

# %%
filename = "Population"
filepath = os.path.join("../Raw", filename)

df = pd.read_csv(filepath)
df
# Out:
#                 DATAFLOW        LAST UPDATE    freq  \
# 0    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 1    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 2    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 3    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 4    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# ..                   ...                ...     ...
# 576  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 577  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 578  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 579  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 580  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
#
#                             indic_de      geo  TIME_PERIOD  OBS_VALUE  \
# 0    Population on 1 January - total  Andorra         2013      76246
# 1    Population on 1 January - total  Andorra         2016      71732
# 2    Population on 1 January - total  Andorra         2018      74794
# 3    Population on 1 January - total  Andorra         2019      76177
# 4    Population on 1 January - total  Andorra         2020      77543
# ..                               ...      ...          ...        ...
# 576  Population on 1 January - total  Kosovo*         2018    1798506
# 577  Population on 1 January - total  Kosovo*         2019    1795666
# 578  Population on 1 January - total  Kosovo*         2020    1782115
# 579  Population on 1 January - total  Kosovo*         2021    1798186
# 580  Population on 1 January - total  Kosovo*         2022    1773971
#
#     OBS_FLAG  CONF_STATUS
# 0        NaN          NaN
# 1        NaN          NaN
# 2          e          NaN
# 3        NaN          NaN
# 4          e          NaN
# ..       ...          ...
# 576      NaN          NaN
# 577      NaN          NaN
# 578      NaN          NaN
# 579      NaN          NaN
# 580      NaN          NaN
#
# [581 rows x 9 columns]

# %%
# Only countries that exist in util.COUNTRIES class
df = df[df["geo"].isin(list(vars(util.COUNTRIES).values()))]
df
# Out:
#                 DATAFLOW        LAST UPDATE    freq  \
# 0    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 1    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 2    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 3    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 4    ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# ..                   ...                ...     ...
# 526  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 527  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 528  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 529  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
# 530  ESTAT:TPS00001(1.0)  09/01/25 23:00:00  Annual
#
#                             indic_de       geo  TIME_PERIOD  OBS_VALUE  \
# 0    Population on 1 January - total   Andorra         2013      76246
# 1    Population on 1 January - total   Andorra         2016      71732
# 2    Population on 1 January - total   Andorra         2018      74794
# 3    Population on 1 January - total   Andorra         2019      76177
# 4    Population on 1 January - total   Andorra         2020      77543
# ..                               ...       ...          ...        ...
# 526  Population on 1 January - total  Slovakia         2020    5457873
# 527  Population on 1 January - total  Slovakia         2021    5459781
# 528  Population on 1 January - total  Slovakia         2022    5434712
# 529  Population on 1 January - total  Slovakia         2023    5428792
# 530  Population on 1 January - total  Slovakia         2024    5424687
#
#     OBS_FLAG  CONF_STATUS
# 0        NaN          NaN
# 1        NaN          NaN
# 2          e          NaN
# 3        NaN          NaN
# 4          e          NaN
# ..       ...          ...
# 526      NaN          NaN
# 527      NaN          NaN
# 528      NaN          NaN
# 529      NaN          NaN
# 530      NaN          NaN
#
# [479 rows x 9 columns]

# %%
# Now we want to save the cleaned data
# OBS_VALUE: Proportion of population
# TIME_PERIOD: Year
# age_group_start: Min age
# age_group_end: Max age
# geo: Country

df = df.rename(columns={
    "TIME_PERIOD": "Year",
    "OBS_VALUE": "Population",
    "geo": "Country"
})
df = df[["Country", "Year", "Population"]]
df
# Out:
#       Country  Year  Population
# 0     Andorra  2013       76246
# 1     Andorra  2016       71732
# 2     Andorra  2018       74794
# 3     Andorra  2019       76177
# 4     Andorra  2020       77543
# ..        ...   ...         ...
# 526  Slovakia  2020     5457873
# 527  Slovakia  2021     5459781
# 528  Slovakia  2022     5434712
# 529  Slovakia  2023     5428792
# 530  Slovakia  2024     5424687
#
# [479 rows x 3 columns]

# %%
# Save to Clean folder
clean_folder = "/Users/jesper/Desktop/CBS/Thesis 1/Data/Clean"
clean_filepath = os.path.join(clean_folder, filename + ".csv")
df.to_csv(clean_filepath, index=False)
