# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import util

# %%
filename = "R&D_GDP"
filepath = os.path.join("../Raw", filename)

df = pd.read_csv(filepath)
df
# Out:
#                   DATAFLOW        LAST UPDATE    freq  \
# 0     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 1     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 2     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 3     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# ...                    ...                ...     ...
# 4426  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4427  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4428  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4429  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4430  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
#
#                         sectperf                                        unit  \
# 0     Business enterprise sector  Percentage of gross domestic product (GDP)
# 1     Business enterprise sector  Percentage of gross domestic product (GDP)
# 2     Business enterprise sector  Percentage of gross domestic product (GDP)
# 3     Business enterprise sector  Percentage of gross domestic product (GDP)
# 4     Business enterprise sector  Percentage of gross domestic product (GDP)
# ...                          ...                                         ...
# 4426                 All sectors  Percentage of gross domestic product (GDP)
# 4427                 All sectors  Percentage of gross domestic product (GDP)
# 4428                 All sectors  Percentage of gross domestic product (GDP)
# 4429                 All sectors  Percentage of gross domestic product (GDP)
# 4430                 All sectors  Percentage of gross domestic product (GDP)
#
#                 geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  CONF_STATUS
# 0           Austria         2002       1.39      NaN          NaN
# 1           Austria         2004       1.48      NaN          NaN
# 2           Austria         2005       1.67        e          NaN
# 3           Austria         2006       1.67      NaN          NaN
# 4           Austria         2007       1.72      NaN          NaN
# ...             ...          ...        ...      ...          ...
# 4426  United States         2018       2.99        d          NaN
# 4427  United States         2019       3.15        d          NaN
# 4428  United States         2020       3.42        d          NaN
# 4429  United States         2021       3.48       bd          NaN
# 4430  United States         2022       3.59       dp          NaN
#
# [4431 rows x 10 columns]

# %%
# Only countries that exist in util.COUNTRIES class
df = df[df["geo"].isin(list(vars(util.COUNTRIES).values()))]
df
# Out:
#                   DATAFLOW        LAST UPDATE    freq  \
# 0     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 1     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 2     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 3     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4     ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# ...                    ...                ...     ...
# 4360  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4361  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4362  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4363  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
# 4364  ESTAT:SDG_09_10(1.0)  10/12/24 11:00:00  Annual
#
#                         sectperf                                        unit  \
# 0     Business enterprise sector  Percentage of gross domestic product (GDP)
# 1     Business enterprise sector  Percentage of gross domestic product (GDP)
# 2     Business enterprise sector  Percentage of gross domestic product (GDP)
# 3     Business enterprise sector  Percentage of gross domestic product (GDP)
# 4     Business enterprise sector  Percentage of gross domestic product (GDP)
# ...                          ...                                         ...
# 4360                 All sectors  Percentage of gross domestic product (GDP)
# 4361                 All sectors  Percentage of gross domestic product (GDP)
# 4362                 All sectors  Percentage of gross domestic product (GDP)
# 4363                 All sectors  Percentage of gross domestic product (GDP)
# 4364                 All sectors  Percentage of gross domestic product (GDP)
#
#            geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  CONF_STATUS
# 0      Austria         2002       1.39      NaN          NaN
# 1      Austria         2004       1.48      NaN          NaN
# 2      Austria         2005       1.67        e          NaN
# 3      Austria         2006       1.67      NaN          NaN
# 4      Austria         2007       1.72      NaN          NaN
# ...        ...          ...        ...      ...          ...
# 4360  Slovakia         2019       0.82      NaN          NaN
# 4361  Slovakia         2020       0.89      NaN          NaN
# 4362  Slovakia         2021       0.90      NaN          NaN
# 4363  Slovakia         2022       0.98      NaN          NaN
# 4364  Slovakia         2023       1.04      NaN          NaN
#
# [3408 rows x 10 columns]

# %%
# Now we want to save the cleaned data
# OBS_VALUE: Proportion of population
# TIME_PERIOD: Year
# age_group_start: Min age
# age_group_end: Max age
# geo: Country

df = df.rename(columns={
    "TIME_PERIOD": "Year",
    "OBS_VALUE": "R&D_GDP",
    "geo": "Country",
    "sectperf": "Sector"
})
df = df[["Country", "Year", "R&D_GDP", "Sector"]]
df
# Out:
#        Country  Year  R&D_GDP                      Sector
# 0      Austria  2002     1.39  Business enterprise sector
# 1      Austria  2004     1.48  Business enterprise sector
# 2      Austria  2005     1.67  Business enterprise sector
# 3      Austria  2006     1.67  Business enterprise sector
# 4      Austria  2007     1.72  Business enterprise sector
# ...        ...   ...      ...                         ...
# 4360  Slovakia  2019     0.82                 All sectors
# 4361  Slovakia  2020     0.89                 All sectors
# 4362  Slovakia  2021     0.90                 All sectors
# 4363  Slovakia  2022     0.98                 All sectors
# 4364  Slovakia  2023     1.04                 All sectors
#
# [3408 rows x 4 columns]

# %%
# Save to Clean folder
clean_folder = "/Users/jesper/Desktop/CBS/Thesis 1/Data/Clean"
clean_filepath = os.path.join(clean_folder, filename + ".csv")
df.to_csv(clean_filepath, index=False)
